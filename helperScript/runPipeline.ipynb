# %%
#move to workDir
cd /pigeon/tsugi/work/blast_WhatsInSeq/16S_18S_metagenome_test/nanopore/analysis_18S/nextflow
#clone git repository. requires token for private repository. This is readonly access.
git clone https://Tasu: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@github.com/Tasu/nextflow-18SAmplicon.git
git pull

# %%
#update to latest repository, if there is connection error, please wait for several minutes.
cd /home/tsugi/work/blast_WhatsInSeq/16S_18S_metagenome_test/nanopore/analysis_18S/nextflow/nextflow-18SAmplicon
git fetch origin
git checkout master
git reset --hard origin/master
git pull
# Out:
# #update to latest repository, if there is connection error, please wait for several minutes.
# (nfcore)
# cd /home/tsugi/work/blast_WhatsInSeq/16S_18S_metagenome_test/nanopore/analysis_18S/nextflow/nextflow-18SAmplicon
# (nfcore)
# git fetch origin
# fatal: unable to access 'https://Tasu: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@github.com/Tasu/nextflow-18SAmplicon.git/': Failed to connect to github.com port 443: No route to host
# (nfcore)
# git checkout master
# Already on 'master'
# Your branch is up to date with 'origin/master'.
# (nfcore)
# git reset --hard origin/master
# HEAD is now at e7b1563 fix(summary_report): repair heredoc parsing and track BUG-006
# (nfcore)
# git pull
# fatal: unable to access 'https://Tasu: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@github.com/Tasu/nextflow-18SAmplicon.git/': Failed to connect to github.com port 443: No route to host
# (nfcore)
# : 1

# %%
# put amplicon_sorter.py
# generate sampleSheet.csv
# build amplicon_sorter_v2.sif
# modify params.yaml
conda activate nfcore
cd /pigeon/tsugi/work/blast_WhatsInSeq/16S_18S_metagenome_test/nanopore/analysis_18S/nextflow/nextflow-18SAmplicon
# if you want to resume, please comment out rm -r ./work, if you want to restart from scratch, remove work directory.
# rm -r work
rm -r results
nextflow run main.nf -profile singularity -params-file run/params.yaml -resume 1> nextflow.log 2> nextflow.err
# Out:
# # put amplicon_sorter.py
# (nfcore)
# # generate sampleSheet.csv
# (nfcore)
# # build amplicon_sorter_v2.sif
# (nfcore)
# # modify params.yaml
# (nfcore)
# conda activate nfcore
# (nfcore)
# cd /pigeon/tsugi/work/blast_WhatsInSeq/16S_18S_metagenome_test/nanopore/analysis_18S/nextflow/nextflow-18SAmplicon
# (nfcore)
# # rm -r work
# (nfcore)
# rm -r results
# (nfcore)
# nextflow run main.nf -profile singularity -params-file run/params.yaml -resume 1> nextflow.log 2> nextflow.err
# (nfcore)
# : 1

# %%
#preparation of the input directory
cd /home/tsugi/work/blast_WhatsInSeq/16S_18S_metagenome_test/nanopore/analysis_18S/nextflow/nextflow-18SAmplicon/demo/fastq/
pwd
ln -s /pigeon/tsugi/work/rawread/Nanopore/fastq/20260415_TS_ShikabetaMammal/basecalling/pass/barcode28 ./
ln -s /pigeon/tsugi/work/rawread/Nanopore/fastq/20260415_TS_ShikabetaMammal/basecalling/pass/barcode29 ./
ln -s /pigeon/tsugi/work/rawread/Nanopore/fastq/20260415_TS_ShikabetaMammal/basecalling/pass/barcode30 ./
ln -s /pigeon/tsugi/work/rawread/Nanopore/fastq/20260415_TS_ShikabetaMammal/basecalling/pass/barcode31 ./
ls -la
