# %%
conda activate nfcore
nextflow -v
singularity --version
# Out:
# (nfcore)
# nextflow version 22.10.6.5843
# (nfcore)
# singularity version 3.8.6
# (nfcore)
# : 1

# %%
# 新しい環境を作成してインストールする場合
conda create -n nf-env -c bioconda -c conda-forge \
    nextflow=22.10.6 \
    singularity=3.8.6

# 作成した環境を有効化
conda activate nf-env
